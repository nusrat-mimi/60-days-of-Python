# %% [markdown]
# # *Conditional Statement* If Ekse statements is Python

# %%
x = 50
y = 100
if x>y:
    print('x is greater than y')
if y>x:
    print('y is greater than x')
else:
    print('Out')
# Out:
# y is greater than x

# %%
x = 50
y = 100
if x>y:
    print('x is greater than y')
elif y>x:
    print('y is greater than x')
    print('Data science')
    if x!=y:
        print('not equal')
    if x==y:
        print('equal')
else:
    print('Out')
# Out:
# y is greater than x
# Data science
# not equal

# %%
10 % 3 #modulus
# Out:
# 1

# %%
num = float(input('Enter any number: '))

if num % 2 == 0:
    if num % 5 == 0:
        print(num, 'Divisible by 2 and 5')
    else:
        print('No 1')
else:
    print('No 2')
# Out:
# Enter any number:  10
# 10.0 Divisible by 2 and 5

# %%
num = float(input('Enter any number: '))

if num % 2 == 0:
    if num % 5 == 0:
        print(num, 'Divisible by 2 and 5')
    else:
        print('No 1')
else:
    print('No 2')
# Out:
# Enter any number:  8
# No 1

# %%
num = float(input('Enter any number: '))

if num % 2 == 0:
    if num % 5 == 0:
        print(num, 'Divisible by 2 and 5')
    else:
        print('No 1')
else:
    print('No 2')
# Out:
# Enter any number:  25
# No 2

# %% [markdown]
# # Exercise

# %%
#Import Image

# %%
from IPython.display import Image
Image(filename=r'C:\Users\49176\Downloads\electricity.jpeg') #write filename 'r' for taking slash properly

# %%
amount = 0
net_units = float(input('Enter your unit value: '))

if net_units <=100:
    amount = 0
elif 100 < net_units <= 200:
    amount = (net_units-100)*5
elif 200 < net_units:
    amount = 500 + ((net_units-200)*10)

print('The amount is: ',amount)
# Out:
# Enter your unit value:  360
# The amount is:  2100.0
