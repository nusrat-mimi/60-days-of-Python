# %%
import zipfile as zp

zipp = zp.ZipFile('Zipped rename.zip','w')         # w stands for write

zipp.write('CV.docx')
zipp.write('List comprehension.png')
zipp.write('Full sign.jpg')

# %% [markdown]
# # Unzip

# %%
with zp.ZipFile('Zipped rename.zip','r') as file:  # r stands for read
    file.extractall('Temp Unzip')
