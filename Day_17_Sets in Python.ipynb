# %% [markdown]
# # Set{} in Python
# #no indexing_no duplicate value

# %%
set1 = {1,2,3,4,'ai',(1,7,10)}

# %%
set1
# Out:
# {(1, 7, 10), 1, 2, 3, 4, 'ai'}

# %%
type(set1)
# Out:
# set

# %%
set2 = {}
li = []

# %%
type(li)
# Out:
# list

# %%
type(set2)        #blank set is a dictionary, set and dic both use curly {} bracket
# Out:
# dict

# %%
set3 = set()      #to define blank set

# %%
type(set3)
# Out:
# set

# %%
set3
# Out:
# set()

# %%
li
# Out:
# []

# %%
#set is unindexed/unorderd so value is also unchangable

# %%
set1
# Out:
# {(1, 7, 10), 1, 2, 3, 4, 'ai'}

# %%
set1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 set1[0]
#
# TypeError: 'set' object is not subscriptable

# %%
set1.add(100)                            #add single value

# %%
set1
# Out:
# {(1, 7, 10), 1, 100, 2, 3, 4, 'ai'}

# %%
set1.update([10,20,1000,4000])            #add multiple value
set1
# Out:
# {(1, 7, 10), 1, 10, 100, 1000, 2, 20, 3, 4, 4000, 'ai'}

# %%
set1.add(100)                    #duplicate value not possible

# %%
set1
# Out:
# {(1, 7, 10), 1, 10, 100, 1000, 2, 20, 3, 4, 4000, 'ai'}

# %%
set1.remove(1)

# %%
set1
# Out:
# {(1, 7, 10), 10, 100, 1000, 2, 20, 3, 4, 4000, 'ai'}

# %%
set1.remove(10)

# %%
set1
# Out:
# {(1, 7, 10), 100, 1000, 2, 20, 3, 4, 4000, 'ai'}

# %%
set1.remove(10)            #as I already have deleted 10
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 set1.remove(10)            #as I already have deleted 10
#
# KeyError: 10

# %%
set1.discard(10)

# %%
set1                      #the only difference between remove and discard is showing error in remove() but not in discard() if the value is not exist
# Out:
# {(1, 7, 10), 100, 1000, 2, 20, 3, 4, 4000, 'ai'}

# %%
#membership check

# %%
2 in set1
# Out:
# True

# %%
set1.clear()

# %%
set1
# Out:
# set()

# %%
 set2 = {2,3,4,4}

# %%
set2.pop()
# Out:
# 2

# %%
set2
# Out:
# {3, 4}

# %%
set2.pop()
# Out:
# 3

# %%
set2
# Out:
# {4}
