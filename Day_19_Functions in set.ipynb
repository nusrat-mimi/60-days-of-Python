# %%
#Functions in set

# %%
from IPython.display import Image
Image(filename=r'C:\Users\49176\Pictures\Screenshots\Functions in set.png')

# %%
s1 = {1,2,3,4}
s2 = {1,4,'a','b'}

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
s2
# Out:
# {1, 4, 'a', 'b'}

# %%
s3 = frozenset (s2)

# %%
s3
# Out:
# frozenset({1, 4, 'a', 'b'})

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
s1.add('d')

# %%
s1
# Out:
# {1, 2, 3, 4, 'd'}

# %%
s2 = s1

# %%
s2
# Out:
# {1, 2, 3, 4, 'd'}

# %%
s2.remove('d')

# %%
s2
# Out:
# {1, 2, 3, 4}

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
s4 = s1.copy()            #use copy() func so that the main set will not cahnge

# %%
s4
# Out:
# {1, 2, 3, 4}

# %%
s4.remove(1)

# %%
s4
# Out:
# {2, 3, 4}

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
s3
# Out:
# frozenset({1, 4, 'a', 'b'})

# %%
s1.difference(s3)
# Out:
# {2, 3}

# %%
s3.difference(s1)
# Out:
# frozenset({'a', 'b'})

# %%
s1 = {1,2,3}
s2 = {3,4}

# %%
s1.difference(s2)
# Out:
# {1, 2}

# %%
s1.difference_update(s2)

# %%
s1
# Out:
# {1, 2}

# %%
s1
# Out:
# {1, 2}

# %%
s2
# Out:
# {3, 4}

# %%
s1.issubset(s2)
# Out:
# False

# %%
{3}.issubset(s2)
# Out:
# True

# %%
s2.issuperset({4})
# Out:
# True

# %%
s1 = {7,8,1,2}
s2 = {1,2,4,5}

# %%
s1.symmetric_difference(s2)
# Out:
# {4, 5, 7, 8}

# %%
s1.symmetric_difference_update(s2)

# %%
s1
# Out:
# {4, 5, 7, 8}
