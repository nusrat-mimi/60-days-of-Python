# %% [markdown]
# # Frozen set in Python
# #Can't change, add, remove, modify
# #syntex: frozenset(), List, tuple,set everything needs to be declare as a frozen set

# %%
s1 = {1,2,3,4,5}
s2 = {'a','b'}

# %%
s1
# Out:
# {1, 2, 3, 4, 5}

# %%
s2
# Out:
# {'a', 'b'}

# %%
type(s1)
# Out:
# set

# %%
s1.add(10)

# %%
s1
# Out:
# {1, 2, 3, 4, 5, 10}

# %% [markdown]
# # FrozenSet()

# %%
s3 = frozenset(s1)

# %%
s3
# Out:
# frozenset({1, 2, 3, 4, 5, 10})

# %%
type(s3)
# Out:
# frozenset

# %%
s3.add(11)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 s3.add(11)
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
s3.remove(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 s3.remove(3)
#
# AttributeError: 'frozenset' object has no attribute 'remove'

# %%
li = [1,2,3,4,15]
s4 = frozenset(li)

# %%
s4
# Out:
# frozenset({1, 2, 3, 4, 15})

# %%
type(s4)
# Out:
# frozenset

# %%
s4[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 s4[0]
#
# TypeError: 'frozenset' object is not subscriptable

# %%
li[0]
# Out:
# 1

# %% [markdown]
# # Operation possible_eg: union(),intersection()

# %%
s3
# Out:
# frozenset({1, 2, 3, 4, 5, 10})

# %%
s4
# Out:
# frozenset({1, 2, 3, 4, 15})

# %%
s3.union(s4)
# Out:
# frozenset({1, 2, 3, 4, 5, 10, 15})

# %%
s3.intersection(s4)
# Out:
# frozenset({1, 2, 3, 4})

# %%
#string in frozenset

# %%
s = 'data science'

# %%
s
# Out:
# 'data science'

# %%
s5 = frozenset(s)

# %%
s5
# Out:
# frozenset({' ', 'a', 'c', 'd', 'e', 'i', 'n', 's', 't'})

# %%
#to see as list,tuple,set need comprehension

# %%
[list(x) for x in s5]
# Out:
# [['d'], ['s'], ['a'], ['i'], ['n'], ['c'], ['e'], ['t'], [' ']]

# %%
[tuple(x) for x in s5]
# Out:
# [('d',), ('s',), ('a',), ('i',), ('n',), ('c',), ('e',), ('t',), (' ',)]

# %%
[set(x) for x in s5]
# Out:
# [{'d'}, {'s'}, {'a'}, {'i'}, {'n'}, {'c'}, {'e'}, {'t'}, {' '}]
