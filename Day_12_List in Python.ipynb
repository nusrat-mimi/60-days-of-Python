# %% [markdown]
# # *List in Python*

# %%
#list work in a ordered way

# %%
list1 = [2,5,8,10]
list1
# Out:
# [2, 5, 8, 10]

# %%
type(list1) #check data type
# Out:
# list

# %%
list1[2] #check index
# Out:
# 8

# %%
list1[-1]
# Out:
# 10

# %%
list1[1:3]
# Out:
# [5, 8]

# %%
#list changable, mutable

# %%
list1 [0] = 'ai quest'

# %%
list1
# Out:
# ['ai quest', 5, 8, 10]

# %%
#list allowed duplicate

# %%
list1.append('study mart')   #value add

# %%
list1
# Out:
# ['ai quest', 5, 8, 10, 'study mart']

# %%
list1.append('5')

# %%
list1
# Out:
# ['ai quest', 5, 8, 10, 'study mart', '5']

# %%
import sys
sys.getsizeof(list1)
# Out:
# 120

# %%
list1.pop()    #value delet from end
# Out:
# '5'

# %%
list1.pop()
# Out:
# 'study mart'

# %%
list1
# Out:
# ['ai quest', 5, 8, 10]

# %%
list1.pop(0)
# Out:
# 'ai quest'

# %%
list1
# Out:
# [5, 8, 10]

# %%
#creating list using list constructor

# %%
list2 = list(('ai',12, (1,2,3,4)))

# %%
list2
# Out:
# ['ai', 12, (1, 2, 3, 4)]

# %%
type(list2)
# Out:
# list

# %%
list2[2]
# Out:
# (1, 2, 3, 4)

# %%
list2[2][1]
# Out:
# 2

# %%
#input list from user

# %%
list3 =[]

n = int(input('Enter your total index: '))

for i in range(n):
    new = input()
    list3.append(new)
    print(list3)
# Out:
# Enter your total index:  3
#  1
# ['1']
#  2
# ['1', '2']
#  3
# ['1', '2', '3']

# %%
list3 =[]

n = int(input('Enter your total index: '))

for i in range(n):
    new = input()
    list3.append(new)

print(list3)
# Out:
# Enter your total index:  3
#  200
#  33
#  10
# ['200', '33', '10']

# %%
type(list3)
# Out:
# list
